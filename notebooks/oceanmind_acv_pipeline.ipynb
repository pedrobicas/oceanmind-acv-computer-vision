# %% [markdown]
# # OceanMind — ACV Pipeline
# Notebook de apoio para gerar dataset, treinar 2 CNNs do zero e avaliar os resultados.

# %% [markdown]
# ## 1. Instalação
# Execute no terminal: `pip install -r requirements.txt`.

# %%
# !python src/generate_synthetic_ocean_dataset.py --output dataset --images-per-class 220 --size 96

# %%
# !python src/train.py --dataset dataset --epochs 12

# %% [markdown]
# ## 2. Resultados
# Após o treinamento, consulte os gráficos e relatórios na pasta `reports/`.

# %%
import json, pathlib
path = pathlib.Path('reports/model_comparison.json')
if path.exists():
    print(json.dumps(json.loads(path.read_text(encoding='utf-8')), indent=2, ensure_ascii=False)[:3000])
else:
    print('Rode o treinamento primeiro.')
